# %%
import umap
import matplotlib.pyplot as plt
from sklearn.datasets import load_wine
from sklearn.preprocessing import StandardScaler

# Load the Wine dataset
wine = load_wine()
data = wine.data
target = wine.target

# Standardize the data
scaler = StandardScaler()
data_scaled = scaler.fit_transform(data)

# Create a UMAP object
umap_reducer = umap.UMAP(n_neighbors=15, min_dist=0.1, n_components=2, random_state=42)

# Fit and transform the data
embedding = umap_reducer.fit_transform(data_scaled)

# Plot the result
plt.figure(figsize=(8, 6))
plt.scatter(embedding[:, 0], embedding[:, 1], c=target, cmap='viridis', s=50)
plt.colorbar(label='Target')
plt.title('UMAP projection of the Wine dataset')
plt.xlabel('UMAP 1')
plt.ylabel('UMAP 2')
plt.show()
# Out:
# C:\Users\PC\AppData\Local\Programs\Python\Python311\Lib\site-packages\umap\umap_.py:1945: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")
